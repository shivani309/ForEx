# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
usdInr = pd.read_csv(r'C:/Users/uzmap/Documents/GitHub/ForEx/USDINR/USDINR.csv')
usdInr.drop('Unnamed: 0', axis=1, inplace=True)
usdInr.head()
# Out:
#          Date  Open_price  Day_high  Day_low  Closing_price Currency Pair  \
# 0  2014-11-07      61.390    61.620   61.340         61.400       USD/INR
# 1  2014-11-10      61.500    61.635   61.340         61.495       USD/INR
# 2  2014-11-11      61.530    61.555   61.505         61.508       USD/INR
# 3  2014-11-12      61.508    61.560   61.350         61.391       USD/INR
# 4  2014-11-13      61.368    61.623   61.350         61.565       USD/INR
#
#    Deseasonalized_Day_high  Deseasonalized_Day_low  Deseasonalized_Open_price  \
# 0                61.609403               61.339012                  61.390960
# 1                61.625872               61.330301                  61.492726
# 2                61.546894               61.500125                  61.514536
# 3                61.568238               61.358593                  61.504599
# 4                61.636544               61.351053                  61.386236
#
#       EMA_50    EMA_100    EMA_200  RSI      MACD  Signal_Line  \
# 0  61.400000  61.400000  61.400000  0.0  0.000000     0.000000
# 1  61.403725  61.401881  61.400945  0.0  0.007578     0.001516
# 2  61.407815  61.403983  61.402010  0.0  0.014466     0.004106
# 3  61.407155  61.403725  61.401901  0.0  0.010365     0.005358
# 4  61.413345  61.406919  61.403524  0.0  0.020914     0.008469
#
#    MACD_Histogram      SMA  Upper Band  Lower Band
# 0        0.000000  61.7496   62.164424   61.334776
# 1        0.006063  61.7496   62.164424   61.334776
# 2        0.010361  61.7496   62.164424   61.334776
# 3        0.005007  61.7496   62.164424   61.334776
# 4        0.012445  61.7496   62.164424   61.334776

# %%
X = pd.read_csv(r'C:/Users/uzmap/Documents/GitHub/ForEx/USDINR/X_USDINR.csv')
X.drop('Unnamed: 0', axis=1, inplace=True)
X.head()
# Out:
#    Deseasonalized_Day_high  Deseasonalized_Day_low  Deseasonalized_Open_price  \
# 0                 0.002366                0.003777                   0.002111
# 1                 0.002990                0.003444                   0.005988
# 2                 0.000000                0.009943                   0.006819
# 3                 0.000808                0.004527                   0.006440
# 4                 0.003394                0.004238                   0.001931
#
#      EMA_50   EMA_100   EMA_200  RSI      MACD  Signal_Line  MACD_Histogram  \
# 0  0.000000  0.000000  0.000000  0.0  0.435743     0.428316        0.501290
# 1  0.000148  0.000077  0.000040  0.0  0.440006     0.429330        0.511641
# 2  0.000310  0.000162  0.000085  0.0  0.443880     0.431063        0.518980
# 3  0.000284  0.000152  0.000080  0.0  0.441573     0.431901        0.509839
# 4  0.000529  0.000282  0.000148  0.0  0.447507     0.433982        0.522539
#
#         SMA  Upper Band  Lower Band
# 0  0.000988    0.000382    0.026881
# 1  0.000988    0.000382    0.026881
# 2  0.000988    0.000382    0.026881
# 3  0.000988    0.000382    0.026881
# 4  0.000988    0.000382    0.026881

# %%
y = pd.read_csv(r'C:/Users/uzmap/Documents/GitHub/ForEx/USDINR/Y_USDINR.csv')
y.drop('Unnamed: 0', axis=1, inplace=True)
y.head()
# Out:
#    Closing_price
# 0         61.400
# 1         61.495
# 2         61.508
# 3         61.391
# 4         61.565

# %%
import numpy as np

def evaluate_trading_metrics(y_true, y_pred, initial_capital=1000):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()

    # Ensure lengths match
    min_len = min(len(y_true), len(y_pred))
    y_true = y_true[:min_len]
    y_pred = y_pred[:min_len]

    # Compute directional accuracy
    true_diff = np.sign(np.diff(y_true))
    pred_diff = np.sign(np.diff(y_pred))
    correct = np.sum(true_diff == pred_diff)
    trading_accuracy = correct / len(true_diff) * 100

    # Simulate trading strategy
    capital = [initial_capital]
    for i in range(1, len(y_pred)):
        # If model says price will go up -> buy (position = +1)
        # If model says price will go down -> short (position = -1)
        position = 1 if y_pred[i] > y_pred[i - 1] else -1
        profit = position * (y_true[i] - y_true[i - 1])
        capital.append(capital[-1] + profit)

    capital = np.array(capital)
    returns = np.diff(capital) / capital[:-1]

    # ROI
    roi = (capital[-1] - initial_capital) / initial_capital * 100

    # Sharpe Ratio (assuming risk-free rate is 0)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) > 0 else 0

    # Max Drawdown
    peak = np.maximum.accumulate(capital)
    drawdown = (peak - capital) / peak
    max_drawdown = np.max(drawdown) * 100  # as a percentage

    return {
        "Trading Accuracy (%)": trading_accuracy,
        "ROI (%)": roi,
        "Sharpe Ratio": sharpe_ratio,
        "Max Drawdown (%)": max_drawdown
    }

# %%
def directional_accuracy(actual, predicted):
    # Ensure 1D arrays
    actual = np.ravel(actual)
    predicted = np.ravel(predicted)

    # Compute direction change
    actual_diff = np.diff(actual)
    pred_diff = np.diff(predicted)

    # Compare directions
    correct_direction = np.sign(actual_diff) == np.sign(pred_diff)

    return np.mean(correct_direction) * 100

# %%
def lstm_model(usdInr):
    # Define features (X) and target (y)
    target = 'Closing_price'  # Change to your target column
    features = [col for col in usdInr.columns if col not in ['Date', target]]

    # Separate X and y
    X = usdInr[features]
    y = usdInr[target].values
    X = X.select_dtypes('number').values

    # Normalize X and y
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

    # Create sequences
    sequence_length = 30

    def create_sequences(X, y, sequence_length):
        X_seq, y_seq = [], []
        for i in range(len(X) - sequence_length):
            # Add sequences from X
            X_seq.append(X[i:i + sequence_length])
            # Add the corresponding target from y
            y_seq.append(y[i + sequence_length])
        return np.array(X_seq), np.array(y_seq)

    X_seq, y_seq = create_sequences(X, y, sequence_length)

    # Sequential train-test split (85% train, 15% test)
    split_index = int(len(X_seq) * 0.85)
    X_train, X_test = X_seq[:split_index], X_seq[split_index:]
    y_train, y_test = y_seq[:split_index], y_seq[split_index:]

    # Build LSTM model
    model = Sequential([
        LSTM(64, activation='relu', input_shape=(sequence_length, X_train.shape[2]), return_sequences=False),
        Dropout(0.2),  # Regularization
        Dense(32, activation='relu'),
        Dense(1)  # Output layer for regression
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

    # Evaluate the model
    train_loss, train_mae = model.evaluate(X_train, y_train)
    test_loss, test_mae = model.evaluate(X_test, y_test)

    print(f"Train Loss: {train_loss:.4f}, Train MAE: {train_mae:.4f}")
    print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

    # Make predictions
    y_pred = model.predict(X_test)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

    # Rescale actual test data for comparison
    y_test_rescaled = scaler_y.inverse_transform(y_test.reshape(-1, 1))

    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
    r2 = r2_score(y_test_rescaled, y_pred_rescaled)

    trading_metrics = evaluate_trading_metrics(y_test_rescaled, y_pred_rescaled)
    # Directional Accuracy
    dir_acc = directional_accuracy(y_test_rescaled, y_pred_rescaled)

    lstm_metrics = pd.DataFrame({
        "Metric": ["MAE", "MSE", "MAPE", "R2", "Directional Accuracy%"],
        "Value": [mae, mse, mape, r2, dir_acc]
    })

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_rescaled, label="Actual", color="blue")
    plt.plot(y_pred_rescaled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("LSTM Predictions vs Actual Values")
    plt.xlabel("Time Steps")
    plt.ylabel("Closing Price")
    plt.show()

    # Example of selecting a smaller range of data for clarity:
    sampled_indices = range(0, len(y_test_rescaled), 10)  # Down-sample data to every 10th point
    y_test_sampled = [y_test_rescaled[i] for i in sampled_indices]
    y_pred_sampled = [y_pred_rescaled[i] for i in sampled_indices]

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_sampled, label="Actual", color="blue")
    plt.plot(y_pred_sampled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("RNN Predictions vs Actual Values (Scaled Down)")
    plt.xlabel("Time Steps (Sampled)")
    plt.ylabel("Closing Price")
    plt.show()


    return lstm_metrics, trading_metrics

lstm_metrics_df, trading_metrics = lstm_model(usdInr)
# Out:
# Epoch 1/20
# C:\Users\uzmap\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0195 - mae: 0.0929 - val_loss: 0.0020 - val_mae: 0.0425
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0348 - val_loss: 0.0038 - val_mae: 0.0608
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0318 - val_loss: 0.0032 - val_mae: 0.0559
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0290 - val_loss: 0.0028 - val_mae: 0.0520
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0100 - val_mae: 0.1000
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0071 - val_mae: 0.0839
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3258e-04 - mae: 0.0226 - val_loss: 0.0045 - val_mae: 0.0669
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2299e-04 - mae: 0.0213 - val_loss: 0.0069 - val_mae: 0.0827
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5857e-04 - mae: 0.0201 - val_loss: 0.0073 - val_mae: 0.0852
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8547e-04 - mae: 0.0194 - val_loss: 0.0071 - val_mae: 0.0839
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5537e-04 - mae: 0.0191 - val_loss: 0.0151 - val_mae: 0.1227
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2054e-04 - mae: 0.0182 - val_loss: 0.0126 - val_mae: 0.1121
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3157e-04 - mae: 0.0174 - val_loss: 0.0156 - val_mae: 0.1246
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1997e-04 - mae: 0.0166 - val_loss: 0.0100 - val_mae: 0.0996
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1191e-04 - mae: 0.0148 - val_loss: 0.0140 - val_mae: 0.1181
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5525e-04 - mae: 0.0163 - val_loss: 0.0142 - val_mae: 0.1189
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9084e-04 - mae: 0.0165 - val_loss: 0.0152 - val_mae: 0.1228
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9826e-04 - mae: 0.0146 - val_loss: 0.0158 - val_mae: 0.1254
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2919e-04 - mae: 0.0160 - val_loss: 0.0181 - val_mae: 0.1344
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9199e-04 - mae: 0.0146 - val_loss: 0.0172 - val_mae: 0.1308
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mae: 0.0268
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - mae: 0.1278
# Train Loss: 0.0042, Train MAE: 0.0519
# Test Loss: 0.0172, Test MAE: 0.1308
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
lstm_metrics_df
# Out:
#                   Metric      Value
# 0                    MAE   3.432917
# 1                    MSE  11.839703
# 2                   MAPE   0.040837
# 3                     R2  -6.865126
# 4  Directional Accuracy%  49.376559

# %%
trading_metrics
# Out:
# {'Trading Accuracy (%)': 49.37655860349127,
#  'ROI (%)': 0.03830000000014024,
#  'Sharpe Ratio': 0.007923801617078079,
#  'Max Drawdown (%)': 0.3522943117063404}

# %%
def lstm_model(usdInr):
    # Define features (X) and target (y)
    target = 'Closing_price'  # Change to your target column
    features = [col for col in usdInr.columns if col not in ['Date', target]]

    # Separate X and y
    X = usdInr[features]
    y = usdInr[target].values
    X = X.select_dtypes('number').values

    # Normalize X and y
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

    # Create sequences
    sequence_length = 30

    def create_sequences(X, y, sequence_length):
        X_seq, y_seq = [], []
        for i in range(len(X) - sequence_length):
            # Add sequences from X
            X_seq.append(X[i:i + sequence_length])
            # Add the corresponding target from y
            y_seq.append(y[i + sequence_length])
        return np.array(X_seq), np.array(y_seq)

    X_seq, y_seq = create_sequences(X, y, sequence_length)

    # Sequential train-test split (85% train, 15% test)
    split_index = int(len(X_seq) * 0.85)
    X_train, X_test = X_seq[:split_index], X_seq[split_index:]
    y_train, y_test = y_seq[:split_index], y_seq[split_index:]

    # Build LSTM model
    model = Sequential([
        LSTM(64, activation='relu', input_shape=(sequence_length, X_train.shape[2]), return_sequences=False),
        Dropout(0.2),  # Regularization
        Dense(32, activation='relu'),
        Dense(1)  # Output layer for regression
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

    # Evaluate the model
    train_loss, train_mae = model.evaluate(X_train, y_train)
    test_loss, test_mae = model.evaluate(X_test, y_test)

    print(f"Train Loss: {train_loss:.4f}, Train MAE: {train_mae:.4f}")
    print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

    # Make predictions
    y_pred = model.predict(X_test)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

    # Rescale actual test data for comparison
    y_test_rescaled = scaler_y.inverse_transform(y_test.reshape(-1, 1))

    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
    r2 = r2_score(y_test_rescaled, y_pred_rescaled)

    trading_metrics = evaluate_trading_metrics(y_test_rescaled, y_pred_rescaled)
    # Directional Accuracy
    dir_acc = directional_accuracy(y_test_rescaled, y_pred_rescaled)

    lstm_metrics = pd.DataFrame({
        "Metric": ["MAE", "MSE", "MAPE", "R2", "Directional Accuracy%"],
        "Value": [mae, mse, mape, r2, dir_acc]
    })

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_rescaled, label="Actual", color="blue")
    plt.plot(y_pred_rescaled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("LSTM Predictions vs Actual Values")
    plt.xlabel("Time Steps")
    plt.ylabel("Closing Price")
    plt.show()

    # Example of selecting a smaller range of data for clarity:
    sampled_indices = range(0, len(y_test_rescaled), 10)  # Down-sample data to every 10th point
    y_test_sampled = [y_test_rescaled[i] for i in sampled_indices]
    y_pred_sampled = [y_pred_rescaled[i] for i in sampled_indices]

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_sampled, label="Actual", color="blue")
    plt.plot(y_pred_sampled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("RNN Predictions vs Actual Values (Scaled Down)")
    plt.xlabel("Time Steps (Sampled)")
    plt.ylabel("Closing Price")
    plt.show()


    return lstm_metrics, trading_metrics

lstm_metrics_df, trading_metrics = lstm_model(usdInr)
# Out:
# Epoch 1/50
# C:\Users\uzmap\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0361 - mae: 0.1287 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0394 - val_loss: 6.7732e-04 - val_mae: 0.0225
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0341 - val_loss: 0.0026 - val_mae: 0.0494
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0030 - val_mae: 0.0505
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0070 - val_mae: 0.0828
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0247 - val_loss: 0.0126 - val_mae: 0.1115
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7777e-04 - mae: 0.0227 - val_loss: 0.0094 - val_mae: 0.0961
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4581e-04 - mae: 0.0215 - val_loss: 0.0092 - val_mae: 0.0953
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1015e-04 - mae: 0.0197 - val_loss: 0.0159 - val_mae: 0.1260
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6629e-04 - mae: 0.0195 - val_loss: 0.0123 - val_mae: 0.1106
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3493e-04 - mae: 0.0183 - val_loss: 0.0160 - val_mae: 0.1262
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2347e-04 - mae: 0.0182 - val_loss: 0.0115 - val_mae: 0.1071
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4599e-04 - mae: 0.0169 - val_loss: 0.0181 - val_mae: 0.1345
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9118e-04 - mae: 0.0162 - val_loss: 0.0110 - val_mae: 0.1042
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9377e-04 - mae: 0.0164 - val_loss: 0.0167 - val_mae: 0.1288
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4935e-04 - mae: 0.0152 - val_loss: 0.0204 - val_mae: 0.1424
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7830e-04 - mae: 0.0149 - val_loss: 0.0179 - val_mae: 0.1336
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8552e-04 - mae: 0.0144 - val_loss: 0.0162 - val_mae: 0.1268
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7717e-04 - mae: 0.0160 - val_loss: 0.0121 - val_mae: 0.1098
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0196e-04 - mae: 0.0149 - val_loss: 0.0134 - val_mae: 0.1158
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6976e-04 - mae: 0.0141 - val_loss: 0.0204 - val_mae: 0.1427
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5765e-04 - mae: 0.0140 - val_loss: 0.0127 - val_mae: 0.1123
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1429e-04 - mae: 0.0134 - val_loss: 0.0147 - val_mae: 0.1208
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3739e-04 - mae: 0.0134 - val_loss: 0.0226 - val_mae: 0.1500
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3554e-04 - mae: 0.0140 - val_loss: 0.0153 - val_mae: 0.1234
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0043e-04 - mae: 0.0131 - val_loss: 0.0171 - val_mae: 0.1306
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6802e-04 - mae: 0.0124 - val_loss: 0.0155 - val_mae: 0.1242
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2759e-04 - mae: 0.0149 - val_loss: 0.0182 - val_mae: 0.1344
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8314e-04 - mae: 0.0128 - val_loss: 0.0152 - val_mae: 0.1229
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5391e-04 - mae: 0.0130 - val_loss: 0.0222 - val_mae: 0.1486
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6644e-04 - mae: 0.0125 - val_loss: 0.0209 - val_mae: 0.1440
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3545e-04 - mae: 0.0128 - val_loss: 0.0147 - val_mae: 0.1210
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0134e-04 - mae: 0.0131 - val_loss: 0.0193 - val_mae: 0.1386
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3133e-04 - mae: 0.0126 - val_loss: 0.0206 - val_mae: 0.1432
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2696e-04 - mae: 0.0132 - val_loss: 0.0161 - val_mae: 0.1266
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5966e-04 - mae: 0.0122 - val_loss: 0.0165 - val_mae: 0.1279
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3934e-04 - mae: 0.0116 - val_loss: 0.0155 - val_mae: 0.1241
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0481e-04 - mae: 0.0126 - val_loss: 0.0092 - val_mae: 0.0956
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3558e-04 - mae: 0.0131 - val_loss: 0.0209 - val_mae: 0.1444
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2924e-04 - mae: 0.0111 - val_loss: 0.0172 - val_mae: 0.1308
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8780e-04 - mae: 0.0122 - val_loss: 0.0144 - val_mae: 0.1196
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7611e-04 - mae: 0.0126 - val_loss: 0.0102 - val_mae: 0.1006
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0459e-04 - mae: 0.0183 - val_loss: 0.0166 - val_mae: 0.1284
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4792e-04 - mae: 0.0142 - val_loss: 0.0142 - val_mae: 0.1188
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0655e-04 - mae: 0.0129 - val_loss: 0.0156 - val_mae: 0.1244
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5334e-04 - mae: 0.0120 - val_loss: 0.0202 - val_mae: 0.1418
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2750e-04 - mae: 0.0114 - val_loss: 0.0162 - val_mae: 0.1267
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0246e-04 - mae: 0.0110 - val_loss: 0.0135 - val_mae: 0.1158
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6012e-04 - mae: 0.0119 - val_loss: 0.0192 - val_mae: 0.1380
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4943e-04 - mae: 0.0117 - val_loss: 0.0151 - val_mae: 0.1225
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1022e-04 - mae: 0.0224
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0141 - mae: 0.1184
# Train Loss: 0.0030, Train MAE: 0.0429
# Test Loss: 0.0151, Test MAE: 0.1225
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
trading_metrics
# Out:
# {'Trading Accuracy (%)': 49.37655860349127,
#  'ROI (%)': 0.04750000000008186,
#  'Sharpe Ratio': 0.00981194439900572,
#  'Max Drawdown (%)': 0.32820153953802644}

# %%
lstm_metrics_df
# Out:
#                   Metric      Value
# 0                    MAE   3.216110
# 1                    MSE  10.408751
# 2                   MAPE   0.038250
# 3                     R2  -5.914543
# 4  Directional Accuracy%  49.376559

# %%
def lstm_model(usdInr):
    # Define features (X) and target (y)
    target = 'Closing_price'  # Change to your target column
    features = [col for col in usdInr.columns if col not in ['Date', target]]

    # Separate X and y
    X = usdInr[features]
    y = usdInr[target].values
    X = X.select_dtypes('number').values

    # Normalize X and y
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

    # Create sequences
    sequence_length = 30

    def create_sequences(X, y, sequence_length):
        X_seq, y_seq = [], []
        for i in range(len(X) - sequence_length):
            # Add sequences from X
            X_seq.append(X[i:i + sequence_length])
            # Add the corresponding target from y
            y_seq.append(y[i + sequence_length])
        return np.array(X_seq), np.array(y_seq)

    X_seq, y_seq = create_sequences(X, y, sequence_length)

    # Sequential train-test split (85% train, 15% test)
    split_index = int(len(X_seq) * 0.85)
    X_train, X_test = X_seq[:split_index], X_seq[split_index:]
    y_train, y_test = y_seq[:split_index], y_seq[split_index:]

    # Build LSTM model
    model = Sequential([
        LSTM(64, activation='relu', input_shape=(sequence_length, X_train.shape[2]), return_sequences=False),
        Dropout(0.2),  # Regularization
        Dense(32, activation='relu'),
        Dense(1)  # Output layer for regression
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

    # Evaluate the model
    train_loss, train_mae = model.evaluate(X_train, y_train)
    test_loss, test_mae = model.evaluate(X_test, y_test)

    print(f"Train Loss: {train_loss:.4f}, Train MAE: {train_mae:.4f}")
    print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

    # Make predictions
    y_pred = model.predict(X_test)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

    # Rescale actual test data for comparison
    y_test_rescaled = scaler_y.inverse_transform(y_test.reshape(-1, 1))

    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
    r2 = r2_score(y_test_rescaled, y_pred_rescaled)

    trading_metrics = evaluate_trading_metrics(y_test_rescaled, y_pred_rescaled)
    # Directional Accuracy
    dir_acc = directional_accuracy(y_test_rescaled, y_pred_rescaled)

    lstm_metrics = pd.DataFrame({
        "Metric": ["MAE", "MSE", "MAPE", "R2", "Directional Accuracy%"],
        "Value": [mae, mse, mape, r2, dir_acc]
    })

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_rescaled, label="Actual", color="blue")
    plt.plot(y_pred_rescaled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("LSTM Predictions vs Actual Values")
    plt.xlabel("Time Steps")
    plt.ylabel("Closing Price")
    plt.show()

    # Example of selecting a smaller range of data for clarity:
    sampled_indices = range(0, len(y_test_rescaled), 10)  # Down-sample data to every 10th point
    y_test_sampled = [y_test_rescaled[i] for i in sampled_indices]
    y_pred_sampled = [y_pred_rescaled[i] for i in sampled_indices]

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_sampled, label="Actual", color="blue")
    plt.plot(y_pred_sampled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("RNN Predictions vs Actual Values (Scaled Down)")
    plt.xlabel("Time Steps (Sampled)")
    plt.ylabel("Closing Price")
    plt.show()


    return lstm_metrics, trading_metrics

lstm_metrics_df, trading_metrics = lstm_model(usdInr)
# Out:
# Epoch 1/100
# C:\Users\uzmap\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0338 - mae: 0.1211 - val_loss: 0.0032 - val_mae: 0.0527
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0394 - val_loss: 0.0145 - val_mae: 0.1197
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0303 - val_loss: 0.0070 - val_mae: 0.0822
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0143 - val_mae: 0.1194
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0123 - val_mae: 0.1103
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9181e-04 - mae: 0.0209 - val_loss: 0.0146 - val_mae: 0.1205
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9087e-04 - mae: 0.0102 - val_loss: 0.0226 - val_mae: 0.1499
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9501e-04 - mae: 0.0106 - val_loss: 0.0289 - val_mae: 0.1697
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8928e-04 - mae: 0.0102 - val_loss: 0.0243 - val_mae: 0.1554
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0149e-04 - mae: 0.0104 - val_loss: 0.0284 - val_mae: 0.1683
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8852e-04 - mae: 0.0099 - val_loss: 0.0235 - val_mae: 0.1528
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6362e-04 - mae: 0.0095 - val_loss: 0.0285 - val_mae: 0.1684
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4834e-04 - mae: 0.0092 - val_loss: 0.0279 - val_mae: 0.1667
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6966e-04 - mae: 0.0098 - val_loss: 0.0263 - val_mae: 0.1618
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6405e-04 - mae: 0.0095 - val_loss: 0.0264 - val_mae: 0.1621
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3436e-04 - mae: 0.0104 - val_loss: 0.0264 - val_mae: 0.1620
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6464e-04 - mae: 0.0095 - val_loss: 0.0303 - val_mae: 0.1736
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6745e-04 - mae: 0.0093 - val_loss: 0.0299 - val_mae: 0.1725
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4101e-04 - mae: 0.0109 - val_loss: 0.0233 - val_mae: 0.1522
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8075e-04 - mae: 0.0116 - val_loss: 0.0298 - val_mae: 0.1722
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0841e-04 - mae: 0.0106 - val_loss: 0.0237 - val_mae: 0.1535
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5668e-04 - mae: 0.0095 - val_loss: 0.0234 - val_mae: 0.1526
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4701e-04 - mae: 0.0092 - val_loss: 0.0259 - val_mae: 0.1606
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3875e-04 - mae: 0.0090 - val_loss: 0.0258 - val_mae: 0.1602
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6779e-04 - mae: 0.0096 - val_loss: 0.0283 - val_mae: 0.1677
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3944e-04 - mae: 0.0090 - val_loss: 0.0237 - val_mae: 0.1535
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mae: 0.0313
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0222 - mae: 0.1487
# Train Loss: 0.0055, Train MAE: 0.0606
# Test Loss: 0.0237, Test MAE: 0.1535
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
lstm_metrics_df
# Out:
#                   Metric      Value
# 0                    MAE   4.028486
# 1                    MSE  16.310317
# 2                   MAPE   0.047915
# 3                     R2  -9.834959
# 4  Directional Accuracy%  49.625935

# %%
trading_metrics
# Out:
# {'Trading Accuracy (%)': 49.62593516209476,
#  'ROI (%)': 0.08430000000012115,
#  'Sharpe Ratio': 0.01736045734324808,
#  'Max Drawdown (%)': 0.3691892432268825}

# %%
def lstm_model(usdInr):
    # Define features (X) and target (y)
    target = 'Closing_price'  # Change to your target column
    features = [col for col in usdInr.columns if col not in ['Date', target]]

    # Separate X and y
    X = usdInr[features]
    y = usdInr[target].values
    X = X.select_dtypes('number').values

    # Normalize X and y
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

    # Create sequences
    sequence_length = 30

    def create_sequences(X, y, sequence_length):
        X_seq, y_seq = [], []
        for i in range(len(X) - sequence_length):
            # Add sequences from X
            X_seq.append(X[i:i + sequence_length])
            # Add the corresponding target from y
            y_seq.append(y[i + sequence_length])
        return np.array(X_seq), np.array(y_seq)

    X_seq, y_seq = create_sequences(X, y, sequence_length)

    # Sequential train-test split (85% train, 15% test)
    split_index = int(len(X_seq) * 0.85)
    X_train, X_test = X_seq[:split_index], X_seq[split_index:]
    y_train, y_test = y_seq[:split_index], y_seq[split_index:]

    # Build LSTM model
    model = Sequential([
        LSTM(64, activation='relu', input_shape=(sequence_length, X_train.shape[2]), return_sequences=False),
        Dropout(0.2),  # Regularization
        Dense(32, activation='relu'),
        Dense(1)  # Output layer for regression
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_test, y_test))

    # Evaluate the model
    train_loss, train_mae = model.evaluate(X_train, y_train)
    test_loss, test_mae = model.evaluate(X_test, y_test)

    print(f"Train Loss: {train_loss:.4f}, Train MAE: {train_mae:.4f}")
    print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

    # Make predictions
    y_pred = model.predict(X_test)
    y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

    # Rescale actual test data for comparison
    y_test_rescaled = scaler_y.inverse_transform(y_test.reshape(-1, 1))

    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
    mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
    r2 = r2_score(y_test_rescaled, y_pred_rescaled)

    trading_metrics = evaluate_trading_metrics(y_test_rescaled, y_pred_rescaled)
    # Directional Accuracy
    dir_acc = directional_accuracy(y_test_rescaled, y_pred_rescaled)

    lstm_metrics = pd.DataFrame({
        "Metric": ["MAE", "MSE", "MAPE", "R2", "Directional Accuracy%"],
        "Value": [mae, mse, mape, r2, dir_acc]
    })

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_rescaled, label="Actual", color="blue")
    plt.plot(y_pred_rescaled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("LSTM Predictions vs Actual Values")
    plt.xlabel("Time Steps")
    plt.ylabel("Closing Price")
    plt.show()

    # Example of selecting a smaller range of data for clarity:
    sampled_indices = range(0, len(y_test_rescaled), 10)  # Down-sample data to every 10th point
    y_test_sampled = [y_test_rescaled[i] for i in sampled_indices]
    y_pred_sampled = [y_pred_rescaled[i] for i in sampled_indices]

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_sampled, label="Actual", color="blue")
    plt.plot(y_pred_sampled, label="Predicted", color="red", linestyle="--")
    plt.legend()
    plt.title("RNN Predictions vs Actual Values (Scaled Down)")
    plt.xlabel("Time Steps (Sampled)")
    plt.ylabel("Closing Price")
    plt.show()


    return lstm_metrics, trading_metrics

lstm_metrics_df, trading_metrics = lstm_model(usdInr)
# Out:
# Epoch 1/500
# C:\Users\uzmap\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0335 - mae: 0.1233 - val_loss: 4.6315e-04 - val_mae: 0.0204
# Epoch 2/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0432 - val_loss: 0.0072 - val_mae: 0.0844
# Epoch 3/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0086 - val_mae: 0.0924
# Epoch 4/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0164 - val_mae: 0.1280
# Epoch 5/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mae: 0.0227 - val_loss: 0.0177 - val_mae: 0.1326
# Epoch 6/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0231 - val_loss: 0.0111 - val_mae: 0.1049
# Epoch 7/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3717e-04 - mae: 0.0226 - val_loss: 0.0180 - val_mae: 0.1341
# Epoch 8/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3465e-04 - mae: 0.0203 - val_loss: 0.0158 - val_mae: 0.1254
# Epoch 9/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2026e-04 - mae: 0.0192 - val_loss: 0.0174 - val_mae: 0.1314
# Epoch 10/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9007e-04 - mae: 0.0171 - val_loss: 0.0166 - val_mae: 0.1286
# Epoch 11/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0525e-04 - mae: 0.0175 - val_loss: 0.0158 - val_mae: 0.1253
# Epoch 12/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.
500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1173e-04 - mae: 0.0078 - val_loss: 0.0273 - val_mae: 0.1647
# Epoch 477/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2765e-04 - mae: 0.0085 - val_loss: 0.0279 - val_mae: 0.1663
# Epoch 478/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1168e-04 - mae: 0.0080 - val_loss: 0.0278 - val_mae: 0.1662
# Epoch 479/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0355e-04 - mae: 0.0076 - val_loss: 0.0289 - val_mae: 0.1694
# Epoch 480/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1819e-04 - mae: 0.0082 - val_loss: 0.0296 - val_mae: 0.1714
# Epoch 481/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9490e-05 - mae: 0.0075 - val_loss: 0.0241 - val_mae: 0.1545
# Epoch 482/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2228e-04 - mae: 0.0084 - val_loss: 0.0250 - val_mae: 0.1575
# Epoch 483/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1777e-04 - mae: 0.0080 - val_loss: 0.0261 - val_mae: 0.1611
# Epoch 484/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1620e-04 - mae: 0.0078 - val_loss: 0.0219 - val_mae: 0.1476
# Epoch 485/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0940e-04 - mae: 0.0079 - val_loss: 0.0327 - val_mae: 0.1803
# Epoch 486/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1279e-04 - mae: 0.0080 - val_loss: 0.0295 - val_mae: 0.1711
# Epoch 487/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0043e-04 - mae: 0.0075 - val_loss: 0.0247 - val_mae: 0.1566
# Epoch 488/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0422e-04 - mae: 0.0078 - val_loss: 0.0255 - val_mae: 0.1590
# Epoch 489/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9788e-05 - mae: 0.0075 - val_loss: 0.0244 - val_mae: 0.1558
# Epoch 490/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3416e-04 - mae: 0.0083 - val_loss: 0.0236 - val_mae: 0.1530
# Epoch 491/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1079e-04 - mae: 0.0078 - val_loss: 0.0243 - val_mae: 0.1553
# Epoch 492/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0876e-04 - mae: 0.0079 - val_loss: 0.0289 - val_mae: 0.1693
# Epoch 493/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0484e-04 - mae: 0.0077 - val_loss: 0.0273 - val_mae: 0.1647
# Epoch 494/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0391e-04 - mae: 0.0077 - val_loss: 0.0272 - val_mae: 0.1644
# Epoch 495/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0510e-04 - mae: 0.0078 - val_loss: 0.0278 - val_mae: 0.1662
# Epoch 496/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3108e-04 - mae: 0.0084 - val_loss: 0.0283 - val_mae: 0.1677
# Epoch 497/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0883e-04 - mae: 0.0077 - val_loss: 0.0292 - val_mae: 0.1702
# Epoch 498/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2417e-04 - mae: 0.0083 - val_loss: 0.0262 - val_mae: 0.1612
# Epoch 499/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0210e-04 - mae: 0.0076 - val_loss: 0.0273 - val_mae: 0.1645
# Epoch 500/500
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3113e-04 - mae: 0.0085 - val_loss: 0.0292 - val_mae: 0.1703
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mae: 0.0331
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0269 - mae: 0.1637
# Train Loss: 0.0061, Train MAE: 0.0637
# Test Loss: 0.0292, Test MAE: 0.1703
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
trading_metrics
# Out:
# {'Trading Accuracy (%)': 49.62593516209476,
#  'ROI (%)': -0.010099999999943066,
#  'Sharpe Ratio': -0.002011845034349711,
#  'Max Drawdown (%)': 0.41137658702380275}

# %%
lstm_metrics_df
# Out:
#                   Metric      Value
# 0                    MAE   4.470099
# 1                    MSE  20.127557
# 2                   MAPE   0.053155
# 3                     R2 -12.370755
# 4  Directional Accuracy%  49.625935
